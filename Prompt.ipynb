# %% [markdown]
# ## 启用封装的函数

# %%
import requests
def chat_vloces(content, syetem_content = "你是一个有用的助手!"):
    url = 'https://ark.cn-beijing.volces.com/api/v3/chat/completions'
    headers = {
        'Authorization': "Bearer 5ba3393a-4042-4d28-8bdb-59683296c03a",
        'Content-Type': 'application/json'  # 添加这个header确保服务器知道我们发送的是JSON数据。
    }
    data = {
        "model": "doubao-lite-32k-240828",
        "messages": [
            {
                "role": "system",
                "content": syetem_content
            },
            {
                "role": "user",
                "content": content
            }
        ],
        "stream": False

    }

    response = requests.post(url, headers=headers, json=data)
    ans = response.json()['choices'][0]['message']['content']
    return(ans)

from openai import OpenAI
def chat_deepseek(content, syetem_content = "你是一个有用的助手!"):
    client = OpenAI(api_key="sk-71850043039a4fdab3fed58fe4cd6203", base_url="https://api.deepseek.com")

    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": syetem_content},
            {"role": "user", "content": content},
        ],
        stream=False  # 启用流式传输
    )

    return(response.choices[0].message.content)

# %% [markdown]
# ## 合同审查
#
# 风险点名称: 约定管辖违反专属管辖或者级别管辖

# %%
## 读取文件
with open("C:/Users/l4241/OneDrive/讲课资料/【清洁版】游泳池租赁承包管理经营协议模板.txt", 'r', encoding='utf-8') as file:
    text = file.read()  # 读取整个文件内容为一个字符串
print(len(text))
# Out:
# 7442

# %% [markdown]
# ### 最简单的合并提示词

# %%
prompt = "约定管辖违反专属管辖或者级别管辖" + text
ans = chat_vloces(prompt)
print(ans)
# Out:
# 请你明确一下具体需求，比如对这份协议进行润色、审查协议条款的合法性与合理性、提取关键信息、根据协议进行案例分析等，以便我更为精准地为你提供服务。

# %%
prompt = "风险点:约定管辖违反专属管辖或者级别管辖" + text
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 请你明确一下你的需求哦，是对这份协议进行分析、提取关键信息还是其他呢？

# %% [markdown]
# 最基础的要求是, 补全要求, 越全越好!

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<合同内容>:
{text}
</合同内容>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# 未违反风险点。合同约定的争议解决方式为提请合同签订地（即深圳市南山区）法院诉讼解决，未涉及约定管辖违反专属管辖或者级别管辖的情况。

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<合同内容>:
{text}
</合同内容>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 根据您提供的合同内容和风险点，合同内容中并未明确涉及“约定管辖违反专属管辖或者级别管辖”的情况。具体分析如下：
#
# 1. **专属管辖**：专属管辖是指某些特定类型的案件只能由特定的法院管辖。例如，不动产纠纷通常由不动产所在地的法院专属管辖。在您提供的合同内容中，涉及的是游泳池租赁承包管理经营协议，属于一般的合同纠纷，不涉及专属管辖的情形。
#
# 2. **级别管辖**：级别管辖是指不同级别的法院对案件的管辖权。例如，基层法院、中级法院、高级法院等对案件的管辖权。在您提供的合同内容中，第十二条“争议解决方式”中约定：“甲、乙双方如在合同履行过程中发生争议，应积极协商解决，协商不成，应提请合同签订地（即深圳市南山区）法院诉讼解决。” 这里约定的管辖法院是合同签订地的基层法院（深圳市南山区法院），并未违反级别管辖的规定。
#
# 综上所述，合同内容中约定的管辖法院并未违反专属管辖或级别管辖的规定，因此不违反您提供的风险点。

# %% [markdown]
# ## 返回的结果不如预期
# 方案一: 追加详细注释

# %%
info = """
专属管辖的简短描述和定义：
专属管辖是指某些特定类型的案件只能由法律明确规定的特定法院审理，其他法院无权管辖。它是一种强制性的管辖规则，当事人不能通过协议改变。

涉及专属管辖的常见情况：
根据《中华人民共和国民事诉讼法》及相关法律规定，以下情形通常涉及专属管辖：

不动产纠纷：
因不动产（如土地、房屋、附着于土地的设施等）的权属、租赁、买卖、抵押等引发的纠纷。

港口作业纠纷：
因港口作业（如装卸、仓储、运输等）引发的纠纷，由港口所在地法院管辖。

继承纠纷：
因遗产继承引发的纠纷，由被继承人死亡时住所地或主要遗产所在地法院管辖。

其他法律规定的情形：
例如：企业破产案件、海事海商案件等，由专门法院或特定法院管辖。
"""

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# 合同中约定的争议解决方式为提请合同签订地（即深圳市南山区）法院诉讼解决，未涉及不动产纠纷、港口作业纠纷、继承纠纷等专属管辖情形，也未违反级别管辖规定，所以不违反所给风险点。

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 根据提供的合同内容和风险点定义，我们可以进行以下分析：
#
# 1. **专属管辖的定义**：专属管辖是指某些特定类型的案件只能由法律明确规定的特定法院审理，其他法院无权管辖。它是一种强制性的管辖规则，当事人不能通过协议改变。
#
# 2. **合同中的争议解决条款**：合同中第十二条规定：“甲、乙双方如在合同履行过程中发生争议，应积极协商解决，协商不成，应提请合同签订地（即深圳市南山区）法院诉讼解决。”
#
# 3. **分析**：
#    - **不动产纠纷**：如果合同涉及的不动产（如游泳池场地）位于深圳市南山区，那么合同约定的管辖法院（深圳市南山区法院）是符合专属管辖规定的。
#    - **其他专属管辖情形**：如果合同涉及的其他事项（如港口作业、继承纠纷等）不在深圳市南山区，那么合同约定的管辖法院可能违反专属管辖规定。
#
# 4. **结论**：
#    - 如果合同仅涉及位于深圳市南山区的游泳池场地租赁，那么合同约定的管辖法院是符合专属管辖规定的，不违反风险点。
#    - 如果合同涉及其他专属管辖事项（如港口作业、继承纠纷等），并且这些事项不在深圳市南山区，那么合同约定的管辖法院可能违反专属管辖规定，存在风险。
#
# 因此，需要进一步确认合同涉及的具体事项是否全部位于深圳市南山区，以确定是否存在违反专属管辖的风险。

# %% [markdown]
# ## 返回的结果不如预期
# 方案二: 逻辑拆分

# %%
prompt1 = f"识别下列租赁合同中, 涉及的不动产的地理位置在哪!\n<租赁合同>:{text}\n</租赁合同>"
ans1 = chat_vloces(prompt1)
print(ans1)

prompt2 = f"识别下列租赁合同中, 不动产实体是什么!\n<租赁合同>:{text}\n</租赁合同>"
ans2 = chat_vloces(prompt2)
print(ans2)

prompt3 = f"识别下列租赁合同中, 管辖法院是什么地方?!\n<租赁合同>:{text}\n</租赁合同>"
ans3 = chat_vloces(prompt3)
print(ans3)

prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
这是一个位于{ans1}的{ans2}的租赁合同, 合同中约定由{ans3}的法院进行管辖
</合同内容>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# 合同中明确提及游泳池位于清远，未提及具体的地理位置信息，仅表明在清远的范围内。
# 不动产实体是位于清远的游泳池场地，包括游泳池及相关的设备设施等。如《游泳池场地及相关的设备设施清单》中所列举的具体内容。
# 合同签订地为深圳市南山区，若双方发生争议，应提请深圳市南山区法院诉讼解决。
# 该合同违反了风险点，约定管辖违反了专属管辖。因为合同中约定的争议由深圳市南山区法院管辖，而合同涉及的不动产是位于清远的游泳池场地，属于不动产纠纷，根据专属管辖规定，不动产纠纷应由不动产所在地法院管辖，即清远的法院管辖，不能通过协议约定由深圳市南山区法院管辖。

# %%
prompt1 = f"识别下列租赁合同中, 涉及的不动产的地理位置在哪!\n<租赁合同>:{text}\n</租赁合同>"
ans1 = chat_deepseek(prompt1)
print(ans1)

prompt2 = f"识别下列租赁合同中, 不动产实体是什么!\n<租赁合同>:{text}\n</租赁合同>"
ans2 = chat_deepseek(prompt2)
print(ans2)

prompt3 = f"识别下列租赁合同中, 管辖法院是什么地方?!\n<租赁合同>:{text}\n</租赁合同>"
ans3 = chat_deepseek(prompt3)
print(ans3)

prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
这是一个位于{ans1}的{ans2}的租赁合同, 合同中约定由{ans3}的法院进行管辖
</合同内容>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 根据租赁合同中的描述，游泳池场地的地理位置位于**清远**。具体位置在合同中没有进一步详细说明，但可以确定的是，该游泳池场地位于清远市。
# 在这份租赁合同中，不动产实体是位于清远的游泳池场地。具体来说，合同的第一条明确指出：
#
# > 1、甲方将位于清远的游泳池场地（以下简称“游泳池场地”）租赁给乙方，经营用途为：游泳培训、游泳比赛活动、业主游泳服务项目，泳池开放时间为        月       日至        月       日，在此期间乙方负责泳池的维护、经营、管理等相关事项并独立承担经营责任，接受甲方的监督。
#
# 因此，不动产实体是位于清远的游泳池场地。
# 根据合同第十二条“争议解决方式”的规定，甲、乙双方如在合同履行过程中发生争议，应积极协商解决，协商不成，应提请合同签订地（即深圳市南山区）法院诉讼解决。因此，管辖法院是深圳市南山区法院。
# 根据您提供的合同内容和风险点定义，我们可以进行以下分析：
#
# 1. **专属管辖的定义**：专属管辖是指某些特定类型的案件只能由法律明确规定的特定法院审理，其他法院无权管辖。这是一种强制性的管辖规则，当事人不能通过协议改变。
#
# 2. **涉及专属管辖的常见情况**：根据《中华人民共和国民事诉讼法》及相关法律规定，不动产纠纷（如土地、房屋、附着于土地的设施等的权属、租赁、买卖、抵押等引发的纠纷）通常涉及专属管辖。
#
# 3. **合同内容分析**：
#    - 合同涉及的不动产实体是位于清远的游泳池场地。
#    - 合同中约定的争议解决方式是：如果甲、乙双方在合同履行过程中发生争议，应积极协商解决，协商不成，应提请合同签订地（即深圳市南山区）法院诉讼解决。
#
# 4. **是否违反专属管辖**：
#    - 由于合同涉及的是不动产（游泳池场地）的租赁纠纷，根据《中华人民共和国民事诉讼法》的规定，这类纠纷应由不动产所在地的法院专属管辖，即清远市的法院。
#    - 合同中约定由深圳市南山区法院管辖，这与专属管辖的规定相冲突。
#
# **结论**：合同中约定的管辖法院（深圳市南山区法院）违反了专属管辖的规定，因为不动产租赁纠纷应由不动产所在地（清远市）的法院专属管辖。因此，该合同条款违反了您给出的风险点。

# %% [markdown]
# ## 返回的结果不如预期
# 方案三: COT (Chain of thought)

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# 1. 合同中明确提及“甲方将位于清远的游泳池场地租赁给乙方”，可知该合同涉及的实体为不动产，位于清远。
# 2. 合同约定争议解决方式为提请合同签订地（即深圳市南山区）法院诉讼解决。
# 3. 由于合同约定的管辖法院（深圳市南山区法院）与不动产所在地（清远）不一致。
# 4. 所以该合同违反了专属管辖，约定管辖违反了专属管辖，不动产纠纷应由不动产所在地法院管辖，而该合同约定了合同签订地的法院管辖。

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 根据提供的合同内容和风险点定义，我们可以按照以下步骤进行分析：
#
# 1. **判断合同涉及的实体是否为不动产**：
#    - 合同内容涉及的是游泳池场地的租赁经营，游泳池场地属于不动产的一部分，因为它附着于土地或建筑物上。因此，合同涉及的实体是不动产。
#
# 2. **识别不动产的地理位置**：
#    - 合同中提到游泳池场地位于清远市。因此，不动产的地理位置是清远市。
#
# 3. **判断合同是否约定了明确的管辖法院**：
#    - 合同第十二条规定：“甲、乙双方如在合同履行过程中发生争议，应积极协商解决，协商不成，应提请合同签订地（即深圳市南山区）法院诉讼解决。” 因此，合同约定了明确的管辖法院，即深圳市南山区法院。
#
# 4. **判断是否违反专属管辖**：
#    - 根据《中华人民共和国民事诉讼法》及相关法律规定，不动产纠纷应由不动产所在地法院专属管辖。在本合同中，不动产位于清远市，因此专属管辖法院应为清远市的法院。
#    - 然而，合同约定由深圳市南山区法院管辖，这与专属管辖的规定相冲突。因此，合同中的管辖约定违反了专属管辖的规定。
#
# 综上所述，该合同违反了风险点中关于专属管辖的规定。

# %% [markdown]
# ## 返回的结果不如预期
# 方案四: 示例

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<违反了专属管辖的示例>:
1.与管辖法院处于不同地方的不动产租赁.
2.与管辖法院处于不同地方的不动产买卖.
3.与管辖法院处于不同地方的不动产委托经营.
</违反了专属管辖的示例>

<没有违反了专属管辖的示例>:
1.借贷.
1.与管辖法院处于相同地方的不动产租赁,买卖和委托经营.
</没有违反了专属管辖的示例>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# 本合同中约定的争议解决方式为提请合同签订地（即深圳市南山区）法院诉讼解决，未涉及不动产纠纷、港口作业纠纷、继承纠纷等专属管辖的情形，也未违反专属管辖或级别管辖的规定。
#
# 综上，该合同未违反风险点中约定管辖违反专属管辖或者级别管辖的规定。

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<违反了专属管辖的示例>:
1.与管辖法院处于不同地方的不动产租赁.
2.与管辖法院处于不同地方的不动产买卖.
3.与管辖法院处于不同地方的不动产委托经营.
</违反了专属管辖的示例>

<没有违反了专属管辖的示例>:
1.借贷.
1.与管辖法院处于相同地方的不动产租赁,买卖和委托经营.
</没有违反了专属管辖的示例>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 根据提供的合同内容和风险点定义，我们可以进行以下分析：
#
# 1. **合同内容**：合同中涉及的游泳池租赁承包管理经营协议，主要涉及的是游泳池场地的租赁和经营管理。合同中明确提到游泳池场地位于清远。
#
# 2. **风险点**：风险点是指合同中的约定管辖是否违反了专属管辖或级别管辖。专属管辖通常涉及不动产纠纷、港口作业纠纷、继承纠纷等特定类型的案件，这些案件只能由法律明确规定的特定法院审理。
#
# 3. **专属管辖的适用**：根据《中华人民共和国民事诉讼法》，不动产纠纷（如土地、房屋、附着于土地的设施等）的权属、租赁、买卖、抵押等引发的纠纷属于专属管辖范围。因此，如果合同涉及的不动产（如游泳池场地）位于特定地点，那么相关纠纷应由该地点的法院管辖。
#
# 4. **合同中的管辖约定**：合同中第十二条“争议解决方式”约定，甲、乙双方如在合同履行过程中发生争议，应积极协商解决，协商不成，应提请合同签订地（即深圳市南山区）法院诉讼解决。
#
# 5. **分析**：
#    - 如果游泳池场地位于清远，而合同约定争议由深圳市南山区法院管辖，那么这种约定可能违反了专属管辖的规定。因为根据专属管辖的原则，不动产纠纷应由不动产所在地的法院管辖，即清远的法院。
#    - 如果游泳池场地位于深圳市南山区，那么合同中的管辖约定是符合专属管辖规定的。
#
# **结论**：
# - 如果游泳池场地位于清远，而合同约定争议由深圳市南山区法院管辖，那么这种约定违反了专属管辖的规定。
# - 如果游泳池场地位于深圳市南山区，那么合同中的管辖约定没有违反专属管辖的规定。
#
# 因此，需要进一步确认游泳池场地的具体位置，以确定合同中的管辖约定是否违反了专属管辖的规定。

# %% [markdown]
# ## 限制性输出
# 减去思考环节

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>

<输出要求>:
参考上面的分析思路进行判断, 但是只输出结果, 不要思考过程, 如果违反了专属管辖则回复"存在风险", 如果没违反专属管辖则回复"不存在风险", 不要输出其他内容.
</输出要求>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# 不存在风险

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>

<输出要求>:
参考上面的分析思路进行判断, 但是只输出结果, 不要思考过程, 如果违反了专属管辖则回复"存在风险", 如果没违反专属管辖则回复"不存在风险", 不要输出其他内容.
</输出要求>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 不存在风险

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>

<输出要求>:
参考上面的分析思路进行判断, 给出简要的分析思路, 以及回复结论, 如果违反了专属管辖则回复"存在风险", 如果没违反专属管辖则回复"不存在风险", 不要输出其他内容.
</输出要求>
"""
ans = chat_vloces(prompt)
print(ans)
# Out:
# <分析思路>
# 1. 合同中明确提到游泳池位于清远，游泳池属于不动产。
# 2. 该不动产位于清远。
# 3. 合同约定争议解决方式为提请合同签订地（即深圳市南山区）法院诉讼解决。
# 4. 合同约定的管辖法院（深圳市南山区法院）与不动产所在地（清远）不一致，违反了专属管辖。
# </分析思路>
# 存在风险

# %%
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>

<输出要求>:
参考上面的分析思路进行判断, 给出简要的分析思路, 以及回复结论, 如果违反了专属管辖则回复"存在风险", 如果没违反专属管辖则回复"不存在风险", 不要输出其他内容.
</输出要求>
"""
ans = chat_deepseek(prompt)
print(ans)
# Out:
# 1. 该合同涉及的实体为游泳池场地，属于不动产。
# 2. 该不动产的地理位置位于清远。
# 3. 合同中约定了明确的管辖法院，即合同签订地深圳市南山区法院。
# 4. 根据《中华人民共和国民事诉讼法》及相关法律规定，不动产纠纷应由不动产所在地法院管辖。因此，合同约定的深圳市南山区法院管辖违反了专属管辖规定。
#
# 存在风险

# %% [markdown]
# ## 限制输出格式:JSON

# %%
import json
prompt = f"""
根据下面给出的合同内容, 判断其是否违反了我给出的风险点:

<风险点>:
风险点:约定管辖违反专属管辖或者级别管辖
</风险点>

<风险定义>:
{info}
</风险定义>

<合同内容>:
{text}
</合同内容>

<分析思路>:
1.请首先判断该合同涉及的实体是否为不动产, 如果是则下一步,如果不是则直接返回不违反风险点.
2.其次识别出该不动产的地理位置在什么地方.
3.判断该合同是否已经约定了明确的管辖法院, 如果有则识别该法院位于什么地方.
4.根据上述结果, 判断是否违反了专属管辖
</分析思路>

<输出要求>:
参考上面的分析思路进行判断, 给出简要的分析思路, 以及回复结论, 如果违反了专属管辖则回复"存在风险", 如果没违反专属管辖则回复"不存在风险", 不要输出其他内容.
</输出要求>

<输出格式>:
输出格式为json, 包括两个key,"分析过程"和"结论", 分别对应分析过程和结论, 分析过程和结论都为字符串格式, 请注意格式要求.
</输出格式>
"""
ans = chat_vloces(prompt)
ans_dict = json.loads(ans)

# %%
ans_dict
# Out:
# {'分析过程': '该合同涉及的实体为游泳池场地，其地理位置在清远。合同约定争议解决方式为提请合同签订地（即深圳市南山区）法院诉讼解决。清远的不动产纠纷应适用专属管辖，而合同约定的管辖法院为深圳市南山区法院，与不动产所在地清远的专属管辖相冲突。',
#  '结论': '存在风险'}

# %% [markdown]
# ## 尝试性题目:
# 判断:
# 文件:QP-04 基础设施和过程运行环境管理程序.pdf
# 要求:
# 医疗器械生产质量管理规范-第三章 厂房与设施-第十四条之二: 厂房应当有适当的照明、温度、湿度和通风控制条件。
#
# 公司内部经验备注:在管理规章里, 必须明确要求了照明,温度, 湿度和通风的指标以及对这些指标才算合格.

# %%
import fitz  # PyMuPDF

def extract_text_with_pymupdf(pdf_path):
    document = fitz.open(pdf_path)
    text = ""
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        text += page.get_text("text")
    return text

text = extract_text_with_pymupdf("C:/Users/l4241/OneDrive/讲课资料/QP-04 基础设施和过程运行环境管理程序.pdf")
print(len(text))
# Out:
# 2271
